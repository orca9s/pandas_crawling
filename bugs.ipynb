# %%
import pandas as pd
from pandas import DataFrame, Series
import requests
import re
import lxml
from bs4 import BeautifulSoup
import numpy as np

# %% [markdown]
# ### 크롤링을 하기 위해 필요한 기본 사항
# 실제로 데이터를 가져올 웹사이트 주소를 chart_url과 같이 변수에 할당해준다.
# 서버에 Request를 보낼 때 안정적인 데이터 확보를 위해 User Agent를 헤더에 담아 URL주소와 headers를 같이 요청한다.
# headers는 선택사항이지만 크롤링을 하기 위해 꼭 넣어서 서버에 요청하는 것을 권장
# 그리고 headers(User Agent)는 브라우저 중에서 호환성이 좋은 FireFox, Chrome을 추천

# %%
chart_url = 'https://music.bugs.co.kr/chart'
headers = {
    'User_agent': 'Mozilla/5.0 (Macintosh; Intel Mac os X x.y; rv:10.0) Gecko/20100101 Firefox/10.0'
}

# %% [markdown]
# ### requests 모듈을 사용하여 Response 200 코드 받기
# - requests 모듈을 사용하여 chart_url을 가져오게 되면 HTTP Response의 응답을 받게 된다. Response 200을 받으면 데이터 파싱이 가능한 상태
# ```
# > res = requests.get(chart_url, headers)<br>
# > res
# # output <Response [200]>
# ```

# %%
res = requests.get(chart_url, headers=headers)
html = res.text

# %% [markdown]
# ### pandas를 사용하여 크롤링
# #### pandas의 자료구조인 data_frame과 series로 크롤링
# > DataFrame은 2차적 데이터 구조 2개 이상의 column이 존재하면 DataFrame이라고 생각
#
# >Series는 1차적 데이터 구조로 1개의 column을 보여주며, Series를 사용하는 이유는 2개의 데이터베이스를 합칠 경우에 index의 순서가 달라도 스마트하게 동일한 index끼리의 처리를 할 수 있기 때문

# %%
type(pd.read_html(html)) # 데이터베이스 테이블이 list타입임을 확인
# Out:
# list

# %%
len(pd.read_html(html)) # 데이터베이스 테이블(리스트)가 3개임을 확인
# Out:
# 3

# %%
chart_df = pd.read_html(html)[0] # 3개의 리스트 중에서 첫번째 리스트 값을 크롤링
chart_df
# Out:
#     Unnamed: 0             순위  Unnamed: 2 Unnamed: 3  \
# 0          NaN        1 0변동없음         NaN        곡정보
# 1          NaN        2 0변동없음         NaN        곡정보
# 2          NaN        3 0변동없음         NaN        곡정보
# 3          NaN        4 0변동없음         NaN        곡정보
# 4          NaN        5 0변동없음         NaN        곡정보
# 5          NaN     6  1 계단 상승         NaN        곡정보
# 6          NaN     7  1 계단 하락         NaN        곡정보
# 7          NaN     8  1 계단 상승         NaN        곡정보
# 8          NaN     9  1 계단 하락         NaN        곡정보
# 9          NaN       10 0변동없음         NaN        곡정보
# 10         NaN       11 0변동없음         NaN        곡정보
# 11         NaN       12 0변동없음         NaN        곡정보
# 12         NaN    13  4 계단 상승         NaN        곡정보
# 13         NaN    14  2 계단 상승         NaN        곡정보
# 14         NaN    15  2 계단 하락         NaN        곡정보
# 15         NaN    16  3 계단 상승         NaN        곡정보
# 16         NaN    17  3 계단 하락         NaN        곡정보
# 17         NaN       18 0변동없음         NaN        곡정보
# 18         NaN    19  6 계단 상승         NaN        곡정보
# 19         NaN    20  6 계단 상승         NaN        곡정보
# 20         NaN    21  2 계단 상승         NaN        곡정보
# 21         NaN    22  2 계단 하락         NaN        곡정보
# 22         NaN    23  2 계단 하락         NaN        곡정보
# 23         NaN    24  9 계단 하락         NaN        곡정보
# 24         NaN    25  9 계단 상승         NaN        곡정보
# 25         NaN    26  2 계단 상승         NaN        곡정보
# 26         NaN    27  3 계단 하락         NaN        곡정보
# 27         NaN    28  2 계단 상승         NaN        곡정보
# 28         NaN    29  7 계단 하락         NaN        곡정보
# 29         NaN    30  2 계단 상승         NaN        곡정보
# ..         ...            ...         ...        ...
# 70         NaN    71  4 계단 상승         NaN        곡정보
# 71         NaN   72  18 계단 하락         NaN        곡정보
# 72         NaN    73  5 계단 상승         NaN        곡정보
# 73         NaN    74  3 계단 상승         NaN        곡정보
# 74         NaN   75  13 계단 상승         NaN        곡정보
# 75         NaN   76  17 계단 상승         NaN        곡정보
# 76         NaN   77  31 계단 하락         NaN        곡정보
# 77         NaN    78  8 계단 하락         NaN        곡정보
# 78         NaN    79  8 계단 하락         NaN        곡정보
# 79         NaN    80  1 계단 상승         NaN        곡정보
# 80         NaN   81  16 계단 상승         NaN        곡정보
# 81         NaN    82  4 계단 상승         NaN        곡정보
# 82         NaN    83  6 계단 상승         NaN        곡정보
# 83         NaN    84  1 계단 하락         NaN        곡정보
# 84         NaN   85  18 계단 상승         NaN        곡정보
# 85         NaN    86  4 계단 하락         NaN        곡정보
# 86         NaN    87  3 계단 하락         NaN        곡정보
# 87         NaN   88  25 계단 하락         NaN        곡정보
# 88         NaN   89  21 계단 하락         NaN        곡정보
# 89         NaN    90  3 계단 하락         NaN        곡정보
# 90         NaN   91  39 계단 하락         NaN        곡정보
# 91         NaN   92  18 계단 하락         NaN        곡정보
# 92         NaN   93  31 계단 하락         NaN        곡정보
# 93         NaN    94  4 계단 하락         NaN        곡정보
# 94         NaN    95  5 계단 상승         NaN        곡정보
# 95         NaN    96  2 계단 하락         NaN        곡정보
# 96         NaN    97  2 계단 상승         NaN        곡정보
# 97         NaN   98  22 계단 하락         NaN        곡정보
# 98         NaN    99  6 계단 상승         NaN        곡정보
# 99         NaN  100  31 계단 상승         NaN        곡정보
#
#                                         곡  \
# 0                               멍청이(twit)
# 1                                    달라달라
# 2                                     오롯이
# 3                         이 노래가 클럽에서 나온다면
# 4              이별을 걷다 (A Walk To Goodbye)
# 5                                  벌써 12시
# 6                                 7 rings
# 7                 신청곡 (Feat. SUGA of BTS)
# 8                    오랜만이야 (Feat. Zion.T)
# 9                       띵 (Prod. By 기리보이)
# 10                                   넘쳐흘러
# 11                         너도 그냥 날 놓아주면 돼
# 12                                   180도
# 13                                    신용재
# 14                                    초록빛
# 15                                   SOLO
# 16                           해야 (Sunrise)
# 17  모든 날, 모든 순간 (Every day, Every Moment)
# 18                             We all lie
# 19                               MILLIONS
# 20                                  너를 만나
# 21                             YES or YES
# 22                          thank u, next
# 23                                그때가 좋았어
# 24                                 %%(응응)
# 25                                    아낙네
# 26                            No Question
# 27                          Way Back Home
# 28                                   WANT
# 29                                    첫눈에
# ..                                    ...
# 70                            Done For Me
# 71                             아름답고도 아프구나
# 72                              그때 헤어지면 돼
# 73                              POP/STARS
# 74                                     선물
# 75                                   명동콜링
# 76                                  흔한 이별
# 77                           첫눈처럼 너에게 가겠다
# 78                            이 밤이 특별해진 건
# 79                                  CLOCK
# 80                      Paris In The Rain
# 81                          나는 볼 수 없던 이야기
# 82                                    알러뷰
# 83                                  Tempo
# 84                                     봄날
# 85                                우리 그만하자
# 86                               I'm Here
# 87                         Roller Coaster
# 88                                  잘 지내요
# 89                    너무 아픈 사랑은 사랑이 아니었음을
# 90                                     행복
# 91                          북향 (Feat. 오혁)
# 92                                  needy
# 93                  섬 (Queen of Diamonds)
# 94                                    옥탑방
# 95                                 꿈처럼 내린
# 96                                  가을 안부
# 97                          Make it count
# 98                                   PIRI
# 99                           [19금] IndiGO
#
#                                        아티스트  \
# 0                                화사(Hwa Sa)
# 1                                 ITZY (있지)
# 2                                헤이즈(HEIZE)
# 3                                 우디(Woody)
# 4                                       황치열
# 5                                        청하
# 6                   Ariana Grande(아리아나 그란데)
# 7                                       이소라
# 8                                        로꼬
# 9                       Jvcki Wai Jvcki Wai
# 10                       엠씨더맥스(M.C THE MAX)
# 11                                       윤건
# 12                                        벤
# 13                                하은(라코스테남)
# 14                             폴킴(Paul Kim)
# 15                              제니 (JENNIE)
# 16                            여자친구(GFRIEND)
# 17                             폴킴(Paul Kim)
# 18                                       하진
# 19                                   WINNER
# 20                             폴킴(Paul Kim)
# 21                             TWICE (트와이스)
# 22                  Ariana Grande(아리아나 그란데)
# 23                                      케이시
# 24                             Apink (에이핑크)
# 25                                MINO(송민호)
# 26      매드 클라운(Mad Clown) 매드 클라운(Mad Clown)
# 27                                 숀(SHAUN)
# 28                              태민 (TAEMIN)
# 29                               헤이즈(HEIZE)
# ..                                      ...
# 70  Charlie Puth(찰리 푸스) Charlie Puth(찰리 푸스)
# 71                                      비투비
# 72                                      로이킴
# 73                          (여자)아이들 (여자)아이들
# 74                          멜로망스(MeloMance)
# 75                    카더가든(Car, the garden)
# 76                                       허각
# 77                               에일리(Ailee)
# 78                     어반 자카파(Urban Zakapa)
# 79                           인피니트(Infinite)
# 80                                Lauv(라우브)
# 81                                      잔나비
# 82                                     EXID
# 83                                      EXO
# 84                                    방탄소년단
# 85                                      로이킴
# 86                                      양다일
# 87                                       청하
# 88                                      정승환
# 89                                      박새별
# 90                                       오반
# 91                                   다이나믹듀오
# 92                  Ariana Grande(아리아나 그란데)
# 93                                     검정치마
# 94                           엔플라잉(N.Flying)
# 95                                      다비치
# 96                       먼데이 키즈(Monday Kiz)
# 97                                 첸 (CHEN)
# 98                       드림캐쳐(Dreamcatcher)
# 99              저스디스(JUSTHIS) 저스디스(JUSTHIS)
#
#                                          앨범  듣기      재생목록       내앨범  \
# 0                                 멍청이(twit)  듣기  재생목록에 추가  내 앨범에 담기
# 1                            IT'z Different  듣기  재생목록에 추가  내 앨범에 담기
# 2                                       오롯이  듣기  재생목록에 추가  내 앨범에 담기
# 3                           이 노래가 클럽에서 나온다면  듣기  재생목록에 추가  내 앨범에 담기
# 4                          The Four Seasons  듣기  재생목록에 추가  내 앨범에 담기
# 5                                    벌써 12시  듣기  재생목록에 추가  내 앨범에 담기
# 6                                   7 rings  듣기  재생목록에 추가  내 앨범에 담기
# 7                   신청곡 (Feat. SUGA of BTS)  듣기  재생목록에 추가  내 앨범에 담기
# 8                                     HELLO  듣기  재생목록에 추가  내 앨범에 담기
# 9                      Dingo X Indigo Music  듣기  재생목록에 추가  내 앨범에 담기
# 10                                 Circular  듣기  재생목록에 추가  내 앨범에 담기
# 11                           너도 그냥 날 놓아주면 돼  듣기  재생목록에 추가  내 앨범에 담기
# 12                                     180˚  듣기  재생목록에 추가  내 앨범에 담기
# 13                                      신용재  듣기  재생목록에 추가  내 앨범에 담기
# 14                                      초록빛  듣기  재생목록에 추가  내 앨범에 담기
# 15                                     SOLO  듣기  재생목록에 추가  내 앨범에 담기
# 16         여자친구 The 2nd Album 'Time for us'  듣기  재생목록에 추가  내 앨범에 담기
# 17                  '키스 먼저 할까요?' OST Part.3  듣기  재생목록에 추가  내 앨범에 담기
# 18         SKY 캐슬 (JTBC 금토드라마) OST - Part.4  듣기  재생목록에 추가  내 앨범에 담기
# 19                                 MILLIONS  듣기  재생목록에 추가  내 앨범에 담기
# 20                                    너를 만나  듣기  재생목록에 추가  내 앨범에 담기
# 21                               YES or YES  듣기  재생목록에 추가  내 앨범에 담기
# 22                            thank u, next  듣기  재생목록에 추가  내 앨범에 담기
# 23                                  그때가 좋았어  듣기  재생목록에 추가  내 앨범에 담기
# 24                                  PERCENT  듣기  재생목록에 추가  내 앨범에 담기
# 25                                       XX  듣기  재생목록에 추가  내 앨범에 담기
# 26                              No Question  듣기  재생목록에 추가  내 앨범에 담기
# 27                                     Take  듣기  재생목록에 추가  내 앨범에 담기
# 28                WANT - The 2nd Mini Album  듣기  재생목록에 추가  내 앨범에 담기
# 29                                      첫눈에  듣기  재생목록에 추가  내 앨범에 담기
# ..                                      ...  ..       ...       ...
# 70                               Voicenotes  듣기  재생목록에 추가  내 앨범에 담기
# 71                              HOUR MOMENT  듣기  재생목록에 추가  내 앨범에 담기
# 72                                그때 헤어지면 돼  듣기  재생목록에 추가  내 앨범에 담기
# 73                                POP/STARS  듣기  재생목록에 추가  내 앨범에 담기
# 74                                Moonlight  듣기  재생목록에 추가  내 앨범에 담기
# 75                        더 팬 2ROUND Part.1  듣기  재생목록에 추가  내 앨범에 담기
# 76                                    흔한 이별  듣기  재생목록에 추가  내 앨범에 담기
# 77             도깨비 (tvN 금토드라마) OST - Part.9  듣기  재생목록에 추가  내 앨범에 담기
# 78                                     [05]  듣기  재생목록에 추가  내 앨범에 담기
# 79                                    CLOCK  듣기  재생목록에 추가  내 앨범에 담기
# 80  I met you when I was 18. (the playlist)  듣기  재생목록에 추가  내 앨범에 담기
# 81       로맨스는 별책부록 (tvN 토일드라마) OST - Part.1  듣기  재생목록에 추가  내 앨범에 담기
# 82                                      알러뷰  듣기  재생목록에 추가  내 앨범에 담기
# 83   DON'T MESS UP MY TEMPO - The 5th Album  듣기  재생목록에 추가  내 앨범에 담기
# 84                     YOU NEVER WALK ALONE  듣기  재생목록에 추가  내 앨범에 담기
# 85                                  우리 그만하자  듣기  재생목록에 추가  내 앨범에 담기
# 86     알함브라 궁전의 추억 (tvN 주말드라마) OST - Part.5  듣기  재생목록에 추가  내 앨범에 담기
# 87                                   Offset  듣기  재생목록에 추가  내 앨범에 담기
# 88                           라이프 OST Part.6  듣기  재생목록에 추가  내 앨범에 담기
# 89     왜그래 풍상씨 (KBS 2TV 수목드라마) OST - Part.4  듣기  재생목록에 추가  내 앨범에 담기
# 90                                       행복  듣기  재생목록에 추가  내 앨범에 담기
# 91                                       북향  듣기  재생목록에 추가  내 앨범에 담기
# 92                            thank u, next  듣기  재생목록에 추가  내 앨범에 담기
# 93                                  THIRSTY  듣기  재생목록에 추가  내 앨범에 담기
# 94                FLY HIGH PROJECT #2 '옥탑방'  듣기  재생목록에 추가  내 앨범에 담기
# 95        뷰티 인사이드 (JTBC 월화드라마) OST - Part.3  듣기  재생목록에 추가  내 앨범에 담기
# 96                                    가을 안부  듣기  재생목록에 추가  내 앨범에 담기
# 97          진심이 닿다 (tvN 수목드라마) OST - Part.1  듣기  재생목록에 추가  내 앨범에 담기
# 98                     The End of Nightmare  듣기  재생목록에 추가  내 앨범에 담기
# 99                                       IM  듣기  재생목록에 추가  내 앨범에 담기
#
#            다운        영상     기타
# 0   flac 다운로드     영상 재생  기타 기능
# 1   flac 다운로드     영상 재생  기타 기능
# 2   flac 다운로드  영상 재생 불가  기타 기능
# 3   flac 다운로드     영상 재생  기타 기능
# 4   flac 다운로드     영상 재생  기타 기능
# 5   flac 다운로드     영상 재생  기타 기능
# 6   flac 다운로드     영상 재생  기타 기능
# 7   flac 다운로드     영상 재생  기타 기능
# 8        다운로드     영상 재생  기타 기능
# 9   flac 다운로드     영상 재생  기타 기능
# 10  flac 다운로드     영상 재생  기타 기능
# 11  flac 다운로드     영상 재생  기타 기능
# 12  flac 다운로드     영상 재생  기타 기능
# 13  flac 다운로드     영상 재생  기타 기능
# 14  flac 다운로드  영상 재생 불가  기타 기능
# 15  flac 다운로드     영상 재생  기타 기능
# 16  flac 다운로드     영상 재생  기타 기능
# 17  flac 다운로드  영상 재생 불가  기타 기능
# 18  flac 다운로드     영상 재생  기타 기능
# 19  flac 다운로드     영상 재생  기타 기능
# 20  flac 다운로드     영상 재생  기타 기능
# 21  flac 다운로드     영상 재생  기타 기능
# 22  flac 다운로드     영상 재생  기타 기능
# 23  flac 다운로드  영상 재생 불가  기타 기능
# 24       다운로드     영상 재생  기타 기능
# 25  flac 다운로드     영상 재생  기타 기능
# 26  flac 다운로드  영상 재생 불가  기타 기능
# 27  flac 다운로드  영상 재생 불가  기타 기능
# 28  flac 다운로드     영상 재생  기타 기능
# 29  flac 다운로드     영상 재생  기타 기능
# ..        ...       ...    ...
# 70  flac 다운로드     영상 재생  기타 기능
# 71  flac 다운로드     영상 재생  기타 기능
# 72  flac 다운로드     영상 재생  기타 기능
# 73  flac 다운로드     영상 재생  기타 기능
# 74  flac 다운로드     영상 재생  기타 기능
# 75  flac 다운로드  영상 재생 불가  기타 기능
# 76  flac 다운로드     영상 재생  기타 기능
# 77  flac 다운로드  영상 재생 불가  기타 기능
# 78  flac 다운로드     영상 재생  기타 기능
# 79  flac 다운로드     영상 재생  기타 기능
# 80  flac 다운로드  영상 재생 불가  기타 기능
# 81  flac 다운로드  영상 재생 불가  기타 기능
# 82  flac 다운로드     영상 재생  기타 기능
# 83  flac 다운로드     영상 재생  기타 기능
# 84  flac 다운로드     영상 재생  기타 기능
# 85  flac 다운로드     영상 재생  기타 기능
# 86  flac 다운로드  영상 재생 불가  기타 기능
# 87  flac 다운로드     영상 재생  기타 기능
# 88  flac 다운로드     영상 재생  기타 기능
# 89  flac 다운로드  영상 재생 불가  기타 기능
# 90  flac 다운로드     영상 재생  기타 기능
# 91  flac 다운로드     영상 재생  기타 기능
# 92  flac 다운로드  영상 재생 불가  기타 기능
# 93  flac 다운로드  영상 재생 불가  기타 기능
# 94  flac 다운로드     영상 재생  기타 기능
# 95  flac 다운로드     영상 재생  기타 기능
# 96  flac 다운로드     영상 재생  기타 기능
# 97  flac 다운로드     영상 재생  기타 기능
# 98  flac 다운로드     영상 재생  기타 기능
# 99  flac 다운로드     영상 재생  기타 기능
#
# [100 rows x 13 columns]

# %% [markdown]
# ## 크롤링한 데이터 프레임의 행과 열을 파악하는 방법 (.shape)

# %%
chart_df.columns
# Out:
# Index(['Unnamed: 0', '순위', 'Unnamed: 2', 'Unnamed: 3', '곡', '아티스트', '앨범', '듣기',
#        '재생목록', '내앨범', '다운', '영상', '기타'],
#       dtype='object')

# %%
pd.DataFrame(chart_df, columns=['순위', '곡', '아티스트', '앨범']).set_index('곡')
# Out:
#                                                   순위  \
# 곡
# 멍청이(twit)                                    1 0변동없음
# 달라달라                                         2 0변동없음
# 오롯이                                          3 0변동없음
# 이 노래가 클럽에서 나온다면                              4 0변동없음
# 이별을 걷다 (A Walk To Goodbye)                   5 0변동없음
# 벌써 12시                                    6  1 계단 상승
# 7 rings                                   7  1 계단 하락
# 신청곡 (Feat. SUGA of BTS)                   8  1 계단 상승
# 오랜만이야 (Feat. Zion.T)                      9  1 계단 하락
# 띵 (Prod. By 기리보이)                           10 0변동없음
# 넘쳐흘러                                        11 0변동없음
# 너도 그냥 날 놓아주면 돼                              12 0변동없음
# 180도                                     13  4 계단 상승
# 신용재                                      14  2 계단 상승
# 초록빛                                      15  2 계단 하락
# SOLO                                     16  3 계단 상승
# 해야 (Sunrise)                             17  3 계단 하락
# 모든 날, 모든 순간 (Every day, Every Moment)       18 0변동없음
# We all lie                               19  6 계단 상승
# MILLIONS                                 20  6 계단 상승
# 너를 만나                                    21  2 계단 상승
# YES or YES                               22  2 계단 하락
# thank u, next                            23  2 계단 하락
# 그때가 좋았어                                  24  9 계단 하락
# %%(응응)                                   25  9 계단 상승
# 아낙네                                      26  2 계단 상승
# No Question                              27  3 계단 하락
# Way Back Home                            28  2 계단 상승
# WANT                                     29  7 계단 하락
# 첫눈에                                      30  2 계단 상승
# ...                                              ...
# Done For Me                              71  4 계단 상승
# 아름답고도 아프구나                              72  18 계단 하락
# 그때 헤어지면 돼                                73  5 계단 상승
# POP/STARS                                74  3 계단 상승
# 선물                                      75  13 계단 상승
# 명동콜링                                    76  17 계단 상승
# 흔한 이별                                   77  31 계단 하락
# 첫눈처럼 너에게 가겠다                             78  8 계단 하락
# 이 밤이 특별해진 건                              79  8 계단 하락
# CLOCK                                    80  1 계단 상승
# Paris In The Rain                       81  16 계단 상승
# 나는 볼 수 없던 이야기                            82  4 계단 상승
# 알러뷰                                      83  6 계단 상승
# Tempo                                    84  1 계단 하락
# 봄날                                      85  18 계단 상승
# 우리 그만하자                                  86  4 계단 하락
# I'm Here                                 87  3 계단 하락
# Roller Coaster                          88  25 계단 하락
# 잘 지내요                                   89  21 계단 하락
# 너무 아픈 사랑은 사랑이 아니었음을                      90  3 계단 하락
# 행복                                      91  39 계단 하락
# 북향 (Feat. 오혁)                           92  18 계단 하락
# needy                                   93  31 계단 하락
# 섬 (Queen of Diamonds)                    94  4 계단 하락
# 옥탑방                                      95  5 계단 상승
# 꿈처럼 내린                                   96  2 계단 하락
# 가을 안부                                    97  2 계단 상승
# Make it count                           98  22 계단 하락
# PIRI                                     99  6 계단 상승
# [19금] IndiGO                           100  31 계단 상승
#
#                                                                           아티스트  \
# 곡
# 멍청이(twit)                                                           화사(Hwa Sa)
# 달라달라                                                                 ITZY (있지)
# 오롯이                                                                 헤이즈(HEIZE)
# 이 노래가 클럽에서 나온다면                                                      우디(Woody)
# 이별을 걷다 (A Walk To Goodbye)                                                 황치열
# 벌써 12시                                                                      청하
# 7 rings                                                Ariana Grande(아리아나 그란데)
# 신청곡 (Feat. SUGA of BTS)                                                    이소라
# 오랜만이야 (Feat. Zion.T)                                                        로꼬
# 띵 (Prod. By 기리보이)                                          Jvcki Wai Jvcki Wai
# 넘쳐흘러                                                        엠씨더맥스(M.C THE MAX)
# 너도 그냥 날 놓아주면 돼                                                              윤건
# 180도                                                                         벤
# 신용재                                                                  하은(라코스테남)
# 초록빛                                                               폴킴(Paul Kim)
# SOLO                                                               제니 (JENNIE)
# 해야 (Sunrise)                                                     여자친구(GFRIEND)
# 모든 날, 모든 순간 (Every day, Every Moment)                             폴킴(Paul Kim)
# We all lie                                                                  하진
# MILLIONS                                                                WINNER
# 너를 만나                                                             폴킴(Paul Kim)
# YES or YES                                                        TWICE (트와이스)
# thank u, next                                          Ariana Grande(아리아나 그란데)
# 그때가 좋았어                                                                    케이시
# %%(응응)                                                            Apink (에이핑크)
# 아낙네                                                                  MINO(송민호)
# No Question                                매드 클라운(Mad Clown) 매드 클라운(Mad Clown)
# Way Back Home                                                         숀(SHAUN)
# WANT                                                               태민 (TAEMIN)
# 첫눈에                                                                 헤이즈(HEIZE)
# ...                                                                        ...
# Done For Me                            Charlie Puth(찰리 푸스) Charlie Puth(찰리 푸스)
# 아름답고도 아프구나                                                                 비투비
# 그때 헤어지면 돼                                                                  로이킴
# POP/STARS                                                      (여자)아이들 (여자)아이들
# 선물                                                             멜로망스(MeloMance)
# 명동콜링                                                     카더가든(Car, the garden)
# 흔한 이별                                                                       허각
# 첫눈처럼 너에게 가겠다                                                        에일리(Ailee)
# 이 밤이 특별해진 건                                               어반 자카파(Urban Zakapa)
# CLOCK                                                           인피니트(Infinite)
# Paris In The Rain                                                    Lauv(라우브)
# 나는 볼 수 없던 이야기                                                              잔나비
# 알러뷰                                                                       EXID
# Tempo                                                                      EXO
# 봄날                                                                       방탄소년단
# 우리 그만하자                                                                    로이킴
# I'm Here                                                                   양다일
# Roller Coaster                                                              청하
# 잘 지내요                                                                      정승환
# 너무 아픈 사랑은 사랑이 아니었음을                                                        박새별
# 행복                                                                          오반
# 북향 (Feat. 오혁)                                                           다이나믹듀오
# needy                                                  Ariana Grande(아리아나 그란데)
# 섬 (Queen of Diamonds)                                                     검정치마
# 옥탑방                                                             엔플라잉(N.Flying)
# 꿈처럼 내린                                                                     다비치
# 가을 안부                                                       먼데이 키즈(Monday Kiz)
# Make it count                                                         첸 (CHEN)
# PIRI                                                        드림캐쳐(Dreamcatcher)
# [19금] IndiGO                                       저스디스(JUSTHIS) 저스디스(JUSTHIS)
#
#                                                                             앨범
# 곡
# 멍청이(twit)                                                            멍청이(twit)
# 달라달라                                                            IT'z Different
# 오롯이                                                                        오롯이
# 이 노래가 클럽에서 나온다면                                                이 노래가 클럽에서 나온다면
# 이별을 걷다 (A Walk To Goodbye)                                    The Four Seasons
# 벌써 12시                                                                  벌써 12시
# 7 rings                                                                7 rings
# 신청곡 (Feat. SUGA of BTS)                                신청곡 (Feat. SUGA of BTS)
# 오랜만이야 (Feat. Zion.T)                                                     HELLO
# 띵 (Prod. By 기리보이)                                         Dingo X Indigo Music
# 넘쳐흘러                                                                  Circular
# 너도 그냥 날 놓아주면 돼                                                  너도 그냥 날 놓아주면 돼
# 180도                                                                      180˚
# 신용재                                                                        신용재
# 초록빛                                                                        초록빛
# SOLO                                                                      SOLO
# 해야 (Sunrise)                                  여자친구 The 2nd Album 'Time for us'
# 모든 날, 모든 순간 (Every day, Every Moment)                  '키스 먼저 할까요?' OST Part.3
# We all lie                                    SKY 캐슬 (JTBC 금토드라마) OST - Part.4
# MILLIONS                                                              MILLIONS
# 너를 만나                                                                    너를 만나
# YES or YES                                                          YES or YES
# thank u, next                                                    thank u, next
# 그때가 좋았어                                                                그때가 좋았어
# %%(응응)                                                                 PERCENT
# 아낙네                                                                         XX
# No Question                                                        No Question
# Way Back Home                                                             Take
# WANT                                                 WANT - The 2nd Mini Album
# 첫눈에                                                                        첫눈에
# ...                                                                        ...
# Done For Me                                                         Voicenotes
# 아름답고도 아프구나                                                         HOUR MOMENT
# 그때 헤어지면 돼                                                            그때 헤어지면 돼
# POP/STARS                                                            POP/STARS
# 선물                                                                   Moonlight
# 명동콜링                                                         더 팬 2ROUND Part.1
# 흔한 이별                                                                    흔한 이별
# 첫눈처럼 너에게 가겠다                                      도깨비 (tvN 금토드라마) OST - Part.9
# 이 밤이 특별해진 건                                                               [05]
# CLOCK                                                                    CLOCK
# Paris In The Rain                      I met you when I was 18. (the playlist)
# 나는 볼 수 없던 이야기                               로맨스는 별책부록 (tvN 토일드라마) OST - Part.1
# 알러뷰                                                                        알러뷰
# Tempo                                   DON'T MESS UP MY TEMPO - The 5th Album
# 봄날                                                        YOU NEVER WALK ALONE
# 우리 그만하자                                                                우리 그만하자
# I'm Here                                  알함브라 궁전의 추억 (tvN 주말드라마) OST - Part.5
# Roller Coaster                                                          Offset
# 잘 지내요                                                           라이프 OST Part.6
# 너무 아픈 사랑은 사랑이 아니었음을                       왜그래 풍상씨 (KBS 2TV 수목드라마) OST - Part.4
# 행복                                                                          행복
# 북향 (Feat. 오혁)                                                               북향
# needy                                                            thank u, next
# 섬 (Queen of Diamonds)                                                  THIRSTY
# 옥탑방                                                  FLY HIGH PROJECT #2 '옥탑방'
# 꿈처럼 내린                                       뷰티 인사이드 (JTBC 월화드라마) OST - Part.3
# 가을 안부                                                                    가을 안부
# Make it count                                  진심이 닿다 (tvN 수목드라마) OST - Part.1
# PIRI                                                      The End of Nightmare
# [19금] IndiGO                                                                IM
#
# [100 rows x 3 columns]

# %% [markdown]
# ### 데이터 프레임에 '좋아요'필드를 추가하고 head, tail을 사용하기
# - .head()는 기본적으로 상위 5개를 출력 따로 옵션을 주고 싶다면() 안에 옵션을 주면된다.
# - .tail()또한 기본적으로 하위 5개를 출력 옵션은 위와 같다

# %%
color_dict = {'blue': '파란색', 'red': '빨간색', 'yellow': '노란색'}

# %%
color_dict
# Out:
# {'blue': '파란색', 'red': '빨간색', 'yellow': '노란색'}

# %%
color_dict['black'] = '검정색'

# %%
color_dict
# Out:
# {'blue': '파란색', 'red': '빨간색', 'yellow': '노란색', 'black': '검정색'}

# %%
chart_df['좋아요'] = 100

# %%
# 정렬 기준에 따라서 레코드값을 1~101까지 설정
# 만약 데이터프레임과 설정하려는 레코드값이 다를 경우 length에러가 발생
# chart_df['좋아요'] = range(1, 30) <-- length에러

chart_df['좋아요'] = range(1, 101)

# %%
chart_df.head(10)
# Out:
#    Unnamed: 0          순위  Unnamed: 2 Unnamed: 3                           곡  \
# 0         NaN     1 0변동없음         NaN        곡정보                   멍청이(twit)
# 1         NaN     2 0변동없음         NaN        곡정보                        달라달라
# 2         NaN     3 0변동없음         NaN        곡정보                         오롯이
# 3         NaN     4 0변동없음         NaN        곡정보             이 노래가 클럽에서 나온다면
# 4         NaN     5 0변동없음         NaN        곡정보  이별을 걷다 (A Walk To Goodbye)
# 5         NaN  6  1 계단 상승         NaN        곡정보                      벌써 12시
# 6         NaN  7  1 계단 하락         NaN        곡정보                     7 rings
# 7         NaN  8  1 계단 상승         NaN        곡정보     신청곡 (Feat. SUGA of BTS)
# 8         NaN  9  1 계단 하락         NaN        곡정보        오랜만이야 (Feat. Zion.T)
# 9         NaN    10 0변동없음         NaN        곡정보           띵 (Prod. By 기리보이)
#
#                       아티스트                       앨범  듣기      재생목록       내앨범  \
# 0               화사(Hwa Sa)                멍청이(twit)  듣기  재생목록에 추가  내 앨범에 담기
# 1                ITZY (있지)           IT'z Different  듣기  재생목록에 추가  내 앨범에 담기
# 2               헤이즈(HEIZE)                      오롯이  듣기  재생목록에 추가  내 앨범에 담기
# 3                우디(Woody)          이 노래가 클럽에서 나온다면  듣기  재생목록에 추가  내 앨범에 담기
# 4                      황치열         The Four Seasons  듣기  재생목록에 추가  내 앨범에 담기
# 5                       청하                   벌써 12시  듣기  재생목록에 추가  내 앨범에 담기
# 6  Ariana Grande(아리아나 그란데)                  7 rings  듣기  재생목록에 추가  내 앨범에 담기
# 7                      이소라  신청곡 (Feat. SUGA of BTS)  듣기  재생목록에 추가  내 앨범에 담기
# 8                       로꼬                    HELLO  듣기  재생목록에 추가  내 앨범에 담기
# 9      Jvcki Wai Jvcki Wai     Dingo X Indigo Music  듣기  재생목록에 추가  내 앨범에 담기
#
#           다운        영상     기타  좋아요
# 0  flac 다운로드     영상 재생  기타 기능    1
# 1  flac 다운로드     영상 재생  기타 기능    2
# 2  flac 다운로드  영상 재생 불가  기타 기능    3
# 3  flac 다운로드     영상 재생  기타 기능    4
# 4  flac 다운로드     영상 재생  기타 기능    5
# 5  flac 다운로드     영상 재생  기타 기능    6
# 6  flac 다운로드     영상 재생  기타 기능    7
# 7  flac 다운로드     영상 재생  기타 기능    8
# 8       다운로드     영상 재생  기타 기능    9
# 9  flac 다운로드     영상 재생  기타 기능   10

# %% [markdown]
# ### .head()옵션
# head 옵션을 사용하면 상위의 지정한 갯수만큼의 필드값을 추출할 수 있다.
# - chart_df.head() # 기본은 5개
# - chart_df.head(50) # 50개의 필드 추출

# %%
chart_df.head()
# Out:
#    Unnamed: 0       순위  Unnamed: 2 Unnamed: 3                           곡  \
# 0         NaN  1 0변동없음         NaN        곡정보                   멍청이(twit)
# 1         NaN  2 0변동없음         NaN        곡정보                        달라달라
# 2         NaN  3 0변동없음         NaN        곡정보                         오롯이
# 3         NaN  4 0변동없음         NaN        곡정보             이 노래가 클럽에서 나온다면
# 4         NaN  5 0변동없음         NaN        곡정보  이별을 걷다 (A Walk To Goodbye)
#
#          아티스트                앨범  듣기      재생목록       내앨범         다운        영상  \
# 0  화사(Hwa Sa)         멍청이(twit)  듣기  재생목록에 추가  내 앨범에 담기  flac 다운로드     영상 재생
# 1   ITZY (있지)    IT'z Different  듣기  재생목록에 추가  내 앨범에 담기  flac 다운로드     영상 재생
# 2  헤이즈(HEIZE)               오롯이  듣기  재생목록에 추가  내 앨범에 담기  flac 다운로드  영상 재생 불가
# 3   우디(Woody)   이 노래가 클럽에서 나온다면  듣기  재생목록에 추가  내 앨범에 담기  flac 다운로드     영상 재생
# 4         황치열  The Four Seasons  듣기  재생목록에 추가  내 앨범에 담기  flac 다운로드     영상 재생
#
#       기타  좋아요
# 0  기타 기능    1
# 1  기타 기능    2
# 2  기타 기능    3
# 3  기타 기능    4
# 4  기타 기능    5

# %% [markdown]
# ### .tail() 옵션
# #### tail 옵션을 사용하면 하위의 지정한 갯수만큼의 필드값을 추출할 수 있다.
# - chart_df.tail() # 기본은 5개
# - chart_df.tail(50) # 50개의 필드 추출

# %%
chart_df.tail()
# Out:
#     Unnamed: 0             순위  Unnamed: 2 Unnamed: 3              곡  \
# 95         NaN    96  2 계단 하락         NaN        곡정보         꿈처럼 내린
# 96         NaN    97  2 계단 상승         NaN        곡정보          가을 안부
# 97         NaN   98  22 계단 하락         NaN        곡정보  Make it count
# 98         NaN    99  6 계단 상승         NaN        곡정보           PIRI
# 99         NaN  100  31 계단 상승         NaN        곡정보   [19금] IndiGO
#
#                            아티스트                                 앨범  듣기  \
# 95                          다비치  뷰티 인사이드 (JTBC 월화드라마) OST - Part.3  듣기
# 96           먼데이 키즈(Monday Kiz)                              가을 안부  듣기
# 97                     첸 (CHEN)    진심이 닿다 (tvN 수목드라마) OST - Part.1  듣기
# 98           드림캐쳐(Dreamcatcher)               The End of Nightmare  듣기
# 99  저스디스(JUSTHIS) 저스디스(JUSTHIS)                                 IM  듣기
#
#         재생목록       내앨범         다운     영상     기타  좋아요
# 95  재생목록에 추가  내 앨범에 담기  flac 다운로드  영상 재생  기타 기능   96
# 96  재생목록에 추가  내 앨범에 담기  flac 다운로드  영상 재생  기타 기능   97
# 97  재생목록에 추가  내 앨범에 담기  flac 다운로드  영상 재생  기타 기능   98
# 98  재생목록에 추가  내 앨범에 담기  flac 다운로드  영상 재생  기타 기능   99
# 99  재생목록에 추가  내 앨범에 담기  flac 다운로드  영상 재생  기타 기능  100

# %% [markdown]
# ### 레코드값을 이용하여 오름차순, 내림차순하기
# 기본옵션은 True로 ascending옵션을 명시할 필요는 없다.

# %%
a = chart_df.sort_values('아티스트', ascending=False)
a[['곡', '아티스트']]
# Out:
#                                                 곡  \
# 4                      이별을 걷다 (A Walk To Goodbye)
# 54                                   그대가 내 안에 박혔다
# 0                                       멍청이(twit)
# 2                                             오롯이
# 29                                            첫눈에
# 76                                          흔한 이별
# 18                                     We all lie
# 13                                            신용재
# 20                                          너를 만나
# 17          모든 날, 모든 순간 (Every day, Every Moment)
# 35                                     사랑 알 수 없나봐
# 14                                            초록빛
# 48                                              비
# 28                                           WANT
# 32                                      내 생에 아름다운
# 23                                        그때가 좋았어
# 75                                           명동콜링
# 97                                  Make it count
# 87                                 Roller Coaster
# 5                                          벌써 12시
# 56                                       그 남자를 떠나
# 30                  길 (Song by 아이유, 헨리, 조현아, 양다일)
# 15                                           SOLO
# 88                                          잘 지내요
# 99                                   [19금] IndiGO
# 46                                           알았다면
# 81                                  나는 볼 수 없던 이야기
# 43                                      이별하러 가는 길
# 59                         하루도 그대를 사랑하지 않은 적이 없었다
# 79                                          CLOCK
# ..                                            ...
# 47                                        너는 어땠을까
# 67                           flex (Prod. By 기리보이)
# 45         행성 (This Night) (Feat. Blue.D, Jhnovr)
# 93                          섬 (Queen of Diamonds)
# 68           Good Day (Feat. 팔로알토) (Prod. 코드 쿤스트)
# 19                                       MILLIONS
# 21                                     YES or YES
# 52                           Dance The Night Away
# 41                   Snowman (삼성 갤럭시 노트 9 광고 삽입곡)
# 63                        Dancing With A Stranger
# 65                           RBB (Really Bad Boy)
# 69                              Bohemian Rhapsody
# 57  Sunflower (Spider-Man: Into the Spider-Verse)
# 25                                            아낙네
# 40                                i'm so tired...
# 80                              Paris In The Rain
# 9                               띵 (Prod. By 기리보이)
# 44                         라비앙로즈 (La Vie en Rose)
# 1                                            달라달라
# 83                                          Tempo
# 49                                      Love Shot
# 82                                            알러뷰
# 70                                    Done For Me
# 38                           뚜두뚜두 (DDU-DU DDU-DU)
# 64                                  Forever Young
# 92                                          needy
# 22                                  thank u, next
# 6                                         7 rings
# 24                                         %%(응응)
# 73                                      POP/STARS
#
#                                        아티스트
# 4                                       황치열
# 54                                      황치열
# 0                                화사(Hwa Sa)
# 2                                헤이즈(HEIZE)
# 29                               헤이즈(HEIZE)
# 76                                       허각
# 18                                       하진
# 13                                하은(라코스테남)
# 20                             폴킴(Paul Kim)
# 17                             폴킴(Paul Kim)
# 35                             폴킴(Paul Kim)
# 14                             폴킴(Paul Kim)
# 48                             폴킴(Paul Kim)
# 28                              태민 (TAEMIN)
# 32                                      케이윌
# 23                                      케이시
# 75                    카더가든(Car, the garden)
# 97                                 첸 (CHEN)
# 87                                       청하
# 5                                        청하
# 56                                 지오디(god)
# 30                                 지오디(god)
# 15                              제니 (JENNIE)
# 88                                      정승환
# 99              저스디스(JUSTHIS) 저스디스(JUSTHIS)
# 46                                      장덕철
# 81                                      잔나비
# 43                                      임한별
# 59                                      임창정
# 79                           인피니트(Infinite)
# ..                                      ...
# 47                                       노을
# 67                                기리보이 기리보이
# 45                        그루비룸 (GroovyRoom)
# 93                                     검정치마
# 68                                pH-1 pH-1
# 19                                   WINNER
# 21                             TWICE (트와이스)
# 52                             TWICE (트와이스)
# 41                                  Sia(시아)
# 63        Sam Smith(샘 스미스) Sam Smith(샘 스미스)
# 65                        Red Velvet (레드벨벳)
# 69                                 Queen(퀸)
# 57  Post Malone(포스트 말론) Post Malone(포스트 말론)
# 25                                MINO(송민호)
# 40                      Lauv(라우브) Lauv(라우브)
# 80                                Lauv(라우브)
# 9                       Jvcki Wai Jvcki Wai
# 44                             IZ*ONE(아이즈원)
# 1                                 ITZY (있지)
# 83                                      EXO
# 49                                      EXO
# 82                                     EXID
# 70  Charlie Puth(찰리 푸스) Charlie Puth(찰리 푸스)
# 38                                BLACKPINK
# 64                                BLACKPINK
# 92                  Ariana Grande(아리아나 그란데)
# 22                  Ariana Grande(아리아나 그란데)
# 6                   Ariana Grande(아리아나 그란데)
# 24                             Apink (에이핑크)
# 73                          (여자)아이들 (여자)아이들
#
# [100 rows x 2 columns]

# %% [markdown]
# ### 좋아요 기준 50개를 넘는 레코드값만 출력하기

# %%
mask = chart_df['좋아요'] > 50
chart_df[mask]
# Out:
#     Unnamed: 0             순위  Unnamed: 2 Unnamed: 3  \
# 50         NaN   51  22 계단 상승         NaN        곡정보
# 51         NaN    52  4 계단 하락         NaN        곡정보
# 52         NaN    53  3 계단 상승         NaN        곡정보
# 53         NaN    54  6 계단 상승         NaN        곡정보
# 54         NaN   55  10 계단 하락         NaN        곡정보
# 55         NaN    56  5 계단 하락         NaN        곡정보
# 56         NaN       57 0변동없음         NaN        곡정보
# 57         NaN    58  3 계단 하락         NaN        곡정보
# 58         NaN   59  13 계단 상승         NaN        곡정보
# 59         NaN   60  20 계단 상승         NaN        곡정보
# 60         NaN    61  2 계단 하락         NaN        곡정보
# 61         NaN   62  29 계단 상승         NaN        곡정보
# 62         NaN    63  1 계단 상승         NaN        곡정보
# 63         NaN   64  11 계단 하락         NaN        곡정보
# 64         NaN   65  27 계단 상승         NaN        곡정보
# 65         NaN   66  13 계단 상승         NaN        곡정보
# 66         NaN    67  2 계단 하락         NaN        곡정보
# 67         NaN   68  17 계단 상승         NaN        곡정보
# 68         NaN    69  2 계단 하락         NaN        곡정보
# 69         NaN    70  1 계단 하락         NaN        곡정보
# 70         NaN    71  4 계단 상승         NaN        곡정보
# 71         NaN   72  18 계단 하락         NaN        곡정보
# 72         NaN    73  5 계단 상승         NaN        곡정보
# 73         NaN    74  3 계단 상승         NaN        곡정보
# 74         NaN   75  13 계단 상승         NaN        곡정보
# 75         NaN   76  17 계단 상승         NaN        곡정보
# 76         NaN   77  31 계단 하락         NaN        곡정보
# 77         NaN    78  8 계단 하락         NaN        곡정보
# 78         NaN    79  8 계단 하락         NaN        곡정보
# 79         NaN    80  1 계단 상승         NaN        곡정보
# 80         NaN   81  16 계단 상승         NaN        곡정보
# 81         NaN    82  4 계단 상승         NaN        곡정보
# 82         NaN    83  6 계단 상승         NaN        곡정보
# 83         NaN    84  1 계단 하락         NaN        곡정보
# 84         NaN   85  18 계단 상승         NaN        곡정보
# 85         NaN    86  4 계단 하락         NaN        곡정보
# 86         NaN    87  3 계단 하락         NaN        곡정보
# 87         NaN   88  25 계단 하락         NaN        곡정보
# 88         NaN   89  21 계단 하락         NaN        곡정보
# 89         NaN    90  3 계단 하락         NaN        곡정보
# 90         NaN   91  39 계단 하락         NaN        곡정보
# 91         NaN   92  18 계단 하락         NaN        곡정보
# 92         NaN   93  31 계단 하락         NaN        곡정보
# 93         NaN    94  4 계단 하락         NaN        곡정보
# 94         NaN    95  5 계단 상승         NaN        곡정보
# 95         NaN    96  2 계단 하락         NaN        곡정보
# 96         NaN    97  2 계단 상승         NaN        곡정보
# 97         NaN   98  22 계단 하락         NaN        곡정보
# 98         NaN    99  6 계단 상승         NaN        곡정보
# 99         NaN  100  31 계단 상승         NaN        곡정보
#
#                                                 곡  \
# 50                                           Home
# 51                                           IDOL
# 52                           Dance The Night Away
# 53                                    Wind flower
# 54                                   그대가 내 안에 박혔다
# 55                                            밤편지
# 56                                       그 남자를 떠나
# 57  Sunflower (Spider-Man: Into the Spider-Verse)
# 58                                           지나오다
# 59                         하루도 그대를 사랑하지 않은 적이 없었다
# 60                                     사이렌(Siren)
# 61                          시간이 들겠지 (Feat. Colde)
# 62                                             여행
# 63                        Dancing With A Stranger
# 64                                  Forever Young
# 65                           RBB (Really Bad Boy)
# 66                              Heu ! (Full Ver.)
# 67                           flex (Prod. By 기리보이)
# 68           Good Day (Feat. 팔로알토) (Prod. 코드 쿤스트)
# 69                              Bohemian Rhapsody
# 70                                    Done For Me
# 71                                     아름답고도 아프구나
# 72                                      그때 헤어지면 돼
# 73                                      POP/STARS
# 74                                             선물
# 75                                           명동콜링
# 76                                          흔한 이별
# 77                                   첫눈처럼 너에게 가겠다
# 78                                    이 밤이 특별해진 건
# 79                                          CLOCK
# 80                              Paris In The Rain
# 81                                  나는 볼 수 없던 이야기
# 82                                            알러뷰
# 83                                          Tempo
# 84                                             봄날
# 85                                        우리 그만하자
# 86                                       I'm Here
# 87                                 Roller Coaster
# 88                                          잘 지내요
# 89                            너무 아픈 사랑은 사랑이 아니었음을
# 90                                             행복
# 91                                  북향 (Feat. 오혁)
# 92                                          needy
# 93                          섬 (Queen of Diamonds)
# 94                                            옥탑방
# 95                                         꿈처럼 내린
# 96                                          가을 안부
# 97                                  Make it count
# 98                                           PIRI
# 99                                   [19금] IndiGO
#
#                                        아티스트  \
# 50                           세븐틴(Seventeen)
# 51                                    방탄소년단
# 52                             TWICE (트와이스)
# 53                             마마무(Mamamoo)
# 54                                      황치열
# 55                                  아이유(IU)
# 56                                 지오디(god)
# 57  Post Malone(포스트 말론) Post Malone(포스트 말론)
# 58                                닐로(Nil_O)
# 59                                      임창정
# 60                                       선미
# 61                                       로꼬
# 62                                   볼빨간사춘기
# 63        Sam Smith(샘 스미스) Sam Smith(샘 스미스)
# 64                                BLACKPINK
# 65                        Red Velvet (레드벨벳)
# 66                                      수퍼비
# 67                                기리보이 기리보이
# 68                                pH-1 pH-1
# 69                                 Queen(퀸)
# 70  Charlie Puth(찰리 푸스) Charlie Puth(찰리 푸스)
# 71                                      비투비
# 72                                      로이킴
# 73                          (여자)아이들 (여자)아이들
# 74                          멜로망스(MeloMance)
# 75                    카더가든(Car, the garden)
# 76                                       허각
# 77                               에일리(Ailee)
# 78                     어반 자카파(Urban Zakapa)
# 79                           인피니트(Infinite)
# 80                                Lauv(라우브)
# 81                                      잔나비
# 82                                     EXID
# 83                                      EXO
# 84                                    방탄소년단
# 85                                      로이킴
# 86                                      양다일
# 87                                       청하
# 88                                      정승환
# 89                                      박새별
# 90                                       오반
# 91                                   다이나믹듀오
# 92                  Ariana Grande(아리아나 그란데)
# 93                                     검정치마
# 94                           엔플라잉(N.Flying)
# 95                                      다비치
# 96                       먼데이 키즈(Monday Kiz)
# 97                                 첸 (CHEN)
# 98                       드림캐쳐(Dreamcatcher)
# 99              저스디스(JUSTHIS) 저스디스(JUSTHIS)
#
#                                                    앨범  듣기      재생목록       내앨범  \
# 50        SEVENTEEN 6TH MINI ALBUM 'YOU MADE MY DAWN'  듣기  재생목록에 추가  내 앨범에 담기
# 51                           LOVE YOURSELF 結 ‘Answer’  듣기  재생목록에 추가  내 앨범에 담기
# 52                                      Summer Nights  듣기  재생목록에 추가  내 앨범에 담기
# 53                                             BLUE;S  듣기  재생목록에 추가  내 앨범에 담기
# 54                                       그대가 내 안에 박혔다  듣기  재생목록에 추가  내 앨범에 담기
# 55                                                밤편지  듣기  재생목록에 추가  내 앨범에 담기
# 56                                         THEN & NOW  듣기  재생목록에 추가  내 앨범에 담기
# 57  스파이더맨: 뉴 유니버스 (Spider-Man: Into the Spider-Ver...  듣기  재생목록에 추가  내 앨범에 담기
# 58                                          About You  듣기  재생목록에 추가  내 앨범에 담기
# 59                             하루도 그대를 사랑하지 않은 적이 없었다  듣기  재생목록에 추가  내 앨범에 담기
# 60                                            WARNING  듣기  재생목록에 추가  내 앨범에 담기
# 61                                            시간이 들겠지  듣기  재생목록에 추가  내 앨범에 담기
# 62                                   Red Diary Page.2  듣기  재생목록에 추가  내 앨범에 담기
# 63                            Dancing With A Stranger  듣기  재생목록에 추가  내 앨범에 담기
# 64                                          SQUARE UP  듣기  재생목록에 추가  내 앨범에 담기
# 65                           RBB - The 5th Mini Album  듣기  재생목록에 추가  내 앨범에 담기
# 66                                  Heu ! (Full Ver.)  듣기  재생목록에 추가  내 앨범에 담기
# 67                               Dingo X Indigo Music  듣기  재생목록에 추가  내 앨범에 담기
# 68                                쇼미더머니 777 Episode 1  듣기  재생목록에 추가  내 앨범에 담기
# 69                   보헤미안 랩소디 (Bohemian Rhapsody) OST  듣기  재생목록에 추가  내 앨범에 담기
# 70                                         Voicenotes  듣기  재생목록에 추가  내 앨범에 담기
# 71                                        HOUR MOMENT  듣기  재생목록에 추가  내 앨범에 담기
# 72                                          그때 헤어지면 돼  듣기  재생목록에 추가  내 앨범에 담기
# 73                                          POP/STARS  듣기  재생목록에 추가  내 앨범에 담기
# 74                                          Moonlight  듣기  재생목록에 추가  내 앨범에 담기
# 75                                  더 팬 2ROUND Part.1  듣기  재생목록에 추가  내 앨범에 담기
# 76                                              흔한 이별  듣기  재생목록에 추가  내 앨범에 담기
# 77                       도깨비 (tvN 금토드라마) OST - Part.9  듣기  재생목록에 추가  내 앨범에 담기
# 78                                               [05]  듣기  재생목록에 추가  내 앨범에 담기
# 79                                              CLOCK  듣기  재생목록에 추가  내 앨범에 담기
# 80            I met you when I was 18. (the playlist)  듣기  재생목록에 추가  내 앨범에 담기
# 81                 로맨스는 별책부록 (tvN 토일드라마) OST - Part.1  듣기  재생목록에 추가  내 앨범에 담기
# 82                                                알러뷰  듣기  재생목록에 추가  내 앨범에 담기
# 83             DON'T MESS UP MY TEMPO - The 5th Album  듣기  재생목록에 추가  내 앨범에 담기
# 84                               YOU NEVER WALK ALONE  듣기  재생목록에 추가  내 앨범에 담기
# 85                                            우리 그만하자  듣기  재생목록에 추가  내 앨범에 담기
# 86               알함브라 궁전의 추억 (tvN 주말드라마) OST - Part.5  듣기  재생목록에 추가  내 앨범에 담기
# 87                                             Offset  듣기  재생목록에 추가  내 앨범에 담기
# 88                                     라이프 OST Part.6  듣기  재생목록에 추가  내 앨범에 담기
# 89               왜그래 풍상씨 (KBS 2TV 수목드라마) OST - Part.4  듣기  재생목록에 추가  내 앨범에 담기
# 90                                                 행복  듣기  재생목록에 추가  내 앨범에 담기
# 91                                                 북향  듣기  재생목록에 추가  내 앨범에 담기
# 92                                      thank u, next  듣기  재생목록에 추가  내 앨범에 담기
# 93                                            THIRSTY  듣기  재생목록에 추가  내 앨범에 담기
# 94                          FLY HIGH PROJECT #2 '옥탑방'  듣기  재생목록에 추가  내 앨범에 담기
# 95                  뷰티 인사이드 (JTBC 월화드라마) OST - Part.3  듣기  재생목록에 추가  내 앨범에 담기
# 96                                              가을 안부  듣기  재생목록에 추가  내 앨범에 담기
# 97                    진심이 닿다 (tvN 수목드라마) OST - Part.1  듣기  재생목록에 추가  내 앨범에 담기
# 98                               The End of Nightmare  듣기  재생목록에 추가  내 앨범에 담기
# 99                                                 IM  듣기  재생목록에 추가  내 앨범에 담기
#
#            다운        영상     기타  좋아요
# 50  flac 다운로드     영상 재생  기타 기능   51
# 51  flac 다운로드     영상 재생  기타 기능   52
# 52  flac 다운로드     영상 재생  기타 기능   53
# 53  flac 다운로드     영상 재생  기타 기능   54
# 54  flac 다운로드     영상 재생  기타 기능   55
# 55  flac 다운로드     영상 재생  기타 기능   56
# 56  flac 다운로드  영상 재생 불가  기타 기능   57
# 57  flac 다운로드  영상 재생 불가  기타 기능   58
# 58  flac 다운로드  영상 재생 불가  기타 기능   59
# 59  flac 다운로드     영상 재생  기타 기능   60
# 60  flac 다운로드     영상 재생  기타 기능   61
# 61  flac 다운로드     영상 재생  기타 기능   62
# 62  flac 다운로드     영상 재생  기타 기능   63
# 63  flac 다운로드     영상 재생  기타 기능   64
# 64  flac 다운로드  영상 재생 불가  기타 기능   65
# 65  flac 다운로드     영상 재생  기타 기능   66
# 66  flac 다운로드  영상 재생 불가  기타 기능   67
# 67  flac 다운로드     영상 재생  기타 기능   68
# 68  flac 다운로드  영상 재생 불가  기타 기능   69
# 69  flac 다운로드  영상 재생 불가  기타 기능   70
# 70  flac 다운로드     영상 재생  기타 기능   71
# 71  flac 다운로드     영상 재생  기타 기능   72
# 72  flac 다운로드     영상 재생  기타 기능   73
# 73  flac 다운로드     영상 재생  기타 기능   74
# 74  flac 다운로드     영상 재생  기타 기능   75
# 75  flac 다운로드  영상 재생 불가  기타 기능   76
# 76  flac 다운로드     영상 재생  기타 기능   77
# 77  flac 다운로드  영상 재생 불가  기타 기능   78
# 78  flac 다운로드     영상 재생  기타 기능   79
# 79  flac 다운로드     영상 재생  기타 기능   80
# 80  flac 다운로드  영상 재생 불가  기타 기능   81
# 81  flac 다운로드  영상 재생 불가  기타 기능   82
# 82  flac 다운로드     영상 재생  기타 기능   83
# 83  flac 다운로드     영상 재생  기타 기능   84
# 84  flac 다운로드     영상 재생  기타 기능   85
# 85  flac 다운로드     영상 재생  기타 기능   86
# 86  flac 다운로드  영상 재생 불가  기타 기능   87
# 87  flac 다운로드     영상 재생  기타 기능   88
# 88  flac 다운로드     영상 재생  기타 기능   89
# 89  flac 다운로드  영상 재생 불가  기타 기능   90
# 90  flac 다운로드     영상 재생  기타 기능   91
# 91  flac 다운로드     영상 재생  기타 기능   92
# 92  flac 다운로드  영상 재생 불가  기타 기능   93
# 93  flac 다운로드  영상 재생 불가  기타 기능   94
# 94  flac 다운로드     영상 재생  기타 기능   95
# 95  flac 다운로드     영상 재생  기타 기능   96
# 96  flac 다운로드     영상 재생  기타 기능   97
# 97  flac 다운로드     영상 재생  기타 기능   98
# 98  flac 다운로드     영상 재생  기타 기능   99
# 99  flac 다운로드     영상 재생  기타 기능  100

# %% [markdown]
# ### 1차적 데이터 구조를 가진 Series
# Series를 사용하는 이유 중에 한가지
# <부산지점><br>
# 백팩: 10 캐리어: 34 커피: 101<br>
# <서울지점><br>
# 캐리어: 3 백팩: 55 커피: 23<br>
# `2지점의 현재 수량은?`<br>
# &total = 부산지점 + 서울지점<br>
# &output: 백팩:65, 캐리어:37, 커피:124<br>
# 이와같이 스마트하게 index를 대조하여 연산이 가능하다.

# %%
obj = pd.Series([3, 5, -1, 2]) # index는 필수로 지정되며, 직접 지정하지 않을 경우에 0, 1, ...와 같이 지정됨
obj
# Out:
# 0    3
# 1    5
# 2   -1
# 3    2
# dtype: int64

# %%
obj.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
obj = pd.Series([3, 5, -1, 2], index=['순이', '영이', '철수', '군자']) # 필요하다면 인덱스를 직접 지정
obj
# Out:
# 순이    3
# 영이    5
# 철수   -1
# 군자    2
# dtype: int64

# %%
obj.index
# Out:
# Index(['순이', '영이', '철수', '군자'], dtype='object')

# %%
obj = pd.Series({'blue': '파란색', 'red':'빨간색', 'yellow':'노란색'}) # dict 타입은 key가 index가 된다

# %%
obj
# Out:
# blue      파란색
# red       빨간색
# yellow    노란색
# dtype: object

# %% [markdown]
# ### key를 활용한 value접근 방법

# %%
obj.red
# Out:
# '빨간색'

# %%
obj['blue']
# Out:
# '파란색'

# %%
type(chart_df['곡'])
# Out:
# pandas.core.series.Series

# %%
chart_df['곡']
# Out:
# 0                                 멍청이(twit)
# 1                                      달라달라
# 2                                       오롯이
# 3                           이 노래가 클럽에서 나온다면
# 4                이별을 걷다 (A Walk To Goodbye)
# 5                                    벌써 12시
# 6                                   7 rings
# 7                   신청곡 (Feat. SUGA of BTS)
# 8                      오랜만이야 (Feat. Zion.T)
# 9                         띵 (Prod. By 기리보이)
# 10                                     넘쳐흘러
# 11                           너도 그냥 날 놓아주면 돼
# 12                                     180도
# 13                                      신용재
# 14                                      초록빛
# 15                                     SOLO
# 16                             해야 (Sunrise)
# 17    모든 날, 모든 순간 (Every day, Every Moment)
# 18                               We all lie
# 19                                 MILLIONS
# 20                                    너를 만나
# 21                               YES or YES
# 22                            thank u, next
# 23                                  그때가 좋았어
# 24                                   %%(응응)
# 25                                      아낙네
# 26                              No Question
# 27                            Way Back Home
# 28                                     WANT
# 29                                      첫눈에
#                       ...
# 70                              Done For Me
# 71                               아름답고도 아프구나
# 72                                그때 헤어지면 돼
# 73                                POP/STARS
# 74                                       선물
# 75                                     명동콜링
# 76                                    흔한 이별
# 77                             첫눈처럼 너에게 가겠다
# 78                              이 밤이 특별해진 건
# 79                                    CLOCK
# 80                        Paris In The Rain
# 81                            나는 볼 수 없던 이야기
# 82                                      알러뷰
# 83                                    Tempo
# 84                                       봄날
# 85                                  우리 그만하자
# 86                                 I'm Here
# 87                           Roller Coaster
# 88                                    잘 지내요
# 89                      너무 아픈 사랑은 사랑이 아니었음을
# 90                                       행복
# 91                            북향 (Feat. 오혁)
# 92                                    needy
# 93                    섬 (Queen of Diamonds)
# 94                                      옥탑방
# 95                                   꿈처럼 내린
# 96                                    가을 안부
# 97                            Make it count
# 98                                     PIRI
# 99                             [19금] IndiGO
# Name: 곡, Length: 100, dtype: object

# %% [markdown]
# ## 크롤링한 데이터 저장하기
# 위에서 크롤링한 데이터를 바로 저장해도 되지만 곡, 아티스트, 앨범만 선택하여 csv, xlsx 파일로 저장하자

# %%
chart_df.columns # 저장할 columns을 확인하자
# Out:
# Index(['Unnamed: 0', '순위', 'Unnamed: 2', 'Unnamed: 3', '곡', '아티스트', '앨범', '듣기',
#        '재생목록', '내앨범', '다운', '영상', '기타', '좋아요'],
#       dtype='object')

# %%
result_chart = chart_df[['곡', '아티스트', '앨범']] # 곡, 아티스트, 앨범을 DataFrame 으로 result_chart에 저장

# %% [markdown]
# ### xlsx파일, csv파일로 저장하기

# %%
result_chart.to_excel('bugs_top_100.xlsx') # pypi 에서 제공하는 openpyxl을 설치하고 엑셀 파일로 저장

# %%
result_chart.to_csv('bugs_top_100.csv') # csv 파일로 저장

# %% [markdown]
# ### 저장한 파일을 다시 불러오기

# %%
pd.read_csv('bugs_top_100.csv').head() # 저장한 csv 파일을 불러오기
# Out:
#    Unnamed: 0                           곡        아티스트                앨범
# 0           0                   멍청이(twit)  화사(Hwa Sa)         멍청이(twit)
# 1           1                        달라달라   ITZY (있지)    IT'z Different
# 2           2                         오롯이  헤이즈(HEIZE)               오롯이
# 3           3             이 노래가 클럽에서 나온다면   우디(Woody)   이 노래가 클럽에서 나온다면
# 4           4  이별을 걷다 (A Walk To Goodbye)         황치열  The Four Seasons

# %%
pd.read_excel('bugs_top_100.xlsx').head(10) # xlrd를 설치, 엑셀파일 불러오기
# Out:
#    Unnamed: 0                           곡                     아티스트  \
# 0           0                   멍청이(twit)               화사(Hwa Sa)
# 1           1                        달라달라                ITZY (있지)
# 2           2                         오롯이               헤이즈(HEIZE)
# 3           3             이 노래가 클럽에서 나온다면                우디(Woody)
# 4           4  이별을 걷다 (A Walk To Goodbye)                      황치열
# 5           5                      벌써 12시                       청하
# 6           6                     7 rings  Ariana Grande(아리아나 그란데)
# 7           7     신청곡 (Feat. SUGA of BTS)                      이소라
# 8           8        오랜만이야 (Feat. Zion.T)                       로꼬
# 9           9           띵 (Prod. By 기리보이)      Jvcki Wai Jvcki Wai
#
#                         앨범
# 0                멍청이(twit)
# 1           IT'z Different
# 2                      오롯이
# 3          이 노래가 클럽에서 나온다면
# 4         The Four Seasons
# 5                   벌써 12시
# 6                  7 rings
# 7  신청곡 (Feat. SUGA of BTS)
# 8                    HELLO
# 9     Dingo X Indigo Music

# %%
# %ls
# Out:
# 10minutes_to_pandas.ipynb   bugs_top_100.csv
# Pipfile                     bugs_top_100.xlsx
# Pipfile.lock                kaggle_titanic_train.csv
# bugs.ipynb                  kaggle_titanic_train.ipynb
